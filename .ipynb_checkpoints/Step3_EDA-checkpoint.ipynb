# %% [markdown]
# # EDA - Exploratory Data Analysis of Used Mercedes Cars

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import seaborn as sns
sns.set_theme(style="darkgrid")

# %%
data = pd.read_csv('data_cleaned.csv')

# %%
data.shape
# Out:
# (11975, 33)

# %%
data.describe()
# Out:
#          Unnamed: 0          price         milage       hubraum           age  \
# count  11975.000000   11975.000000   11975.000000  11974.000000  11975.000000
# mean    6024.099040   40408.145052   93638.727349   2562.195831      5.143166
# std     3480.458919   34249.862902   96666.385779    929.661095      6.115793
# min        0.000000     350.000000       2.000000      1.000000     -1.000000
# 25%     3010.500000    9999.000000   13594.000000   1950.000000      0.083333
# 50%     6020.000000   32900.000000   57560.000000   2148.000000      2.833333
# 75%     9035.500000   63232.000000  154089.500000   2987.000000      9.416667
# max    12071.000000  145000.000000  800000.000000   7180.000000     29.916667
#
#            power_ps      power_kw           amg  mc_laren    blk_series  ...  \
# count  11975.000000  11975.000000  11975.000000   11975.0  11975.000000  ...
# mean     247.088763    181.771888      0.417787       0.0      0.000501  ...
# std      132.328925     97.320970      0.493215       0.0      0.022379  ...
# min        0.000000      0.000000      0.000000       0.0      0.000000  ...
# 25%      160.000000    118.000000      0.000000       0.0      0.000000  ...
# 50%      194.000000    143.000000      0.000000       0.0      0.000000  ...
# 75%      299.000000    220.000000      1.000000       0.0      0.000000  ...
# max      850.000000    625.000000      1.000000       0.0      1.000000  ...
#
#          avantgarde      elegance        tag_63        tag_65        tag_55  \
# count  11975.000000  11975.000000  11975.000000  11975.000000  11975.000000
# mean       0.102965      0.015198      0.077996      0.003674      0.002171
# std        0.303925      0.122346      0.268176      0.060507      0.046547
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000      0.000000
# 50%        0.000000      0.000000      0.000000      0.000000      0.000000
# 75%        0.000000      0.000000      0.000000      0.000000      0.000000
# max        1.000000      1.000000      1.000000      1.000000      1.000000
#
#                 tüv           E10     biodiesel    pflanzenöl      electric
# count  11975.000000  11975.000000  11975.000000  11975.000000  11975.000000
# mean       0.030230      0.076075      0.001336      0.000418      0.061378
# std        0.171226      0.265129      0.036530      0.020430      0.240032
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000      0.000000
# 50%        0.000000      0.000000      0.000000      0.000000      0.000000
# 75%        0.000000      0.000000      0.000000      0.000000      0.000000
# max        1.000000      1.000000      1.000000      1.000000      1.000000
#
# [8 rows x 23 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11975 entries, 0 to 11974
# Data columns (total 33 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      11975 non-null  int64
#  1   carname         11975 non-null  object
#  2   price           11975 non-null  float64
#  3   milage          11975 non-null  float64
#  4   hubraum         11974 non-null  float64
#  5   transmission    11975 non-null  object
#  6   num_seats       11975 non-null  object
#  7   num_doors       11975 non-null  object
#  8   emission_class  11975 non-null  object
#  9   car_type        11975 non-null  object
#  10  num_owners      11975 non-null  object
#  11  age             11975 non-null  float64
#  12  power_ps        11975 non-null  float64
#  13  power_kw        11975 non-null  float64
#  14  Schaden         11975 non-null  object
#  15  Model           11975 non-null  object
#  16  amg             11975 non-null  int64
#  17  mc_laren        11975 non-null  int64
#  18  blk_series      11975 non-null  int64
#  19  blue_eff        11975 non-null  int64
#  20  g_pow           11975 non-null  int64
#  21  brabus          11975 non-null  int64
#  22  avantgarde      11975 non-null  int64
#  23  elegance        11975 non-null  int64
#  24  tag_63          11975 non-null  int64
#  25  tag_65          11975 non-null  int64
#  26  tag_55          11975 non-null  int64
#  27  tüv             11975 non-null  int64
#  28  E10             11975 non-null  int64
#  29  biodiesel       11975 non-null  int64
#  30  pflanzenöl      11975 non-null  int64
#  31  electric        11975 non-null  int64
#  32  fueltype        11975 non-null  object
# dtypes: float64(6), int64(17), object(10)
# memory usage: 3.0+ MB

# %%
# check for columns that contain NaNs
nan_cols = [i for i in data.columns if data[i].isnull().any()]
print(nan_cols)
# Out:
# ['hubraum']

# %% [markdown]
# - There are no NaNs in the Dataset!

# %%
data.head()
# Out:
#    Unnamed: 0                                            carname   price  \
# 0           0  Mercedes-Benz Mercedes vaneo mit 2 jahre tüv t...  1900.0
# 1           1  Mercedes-Benz Mercedes-Benz A 170 Autotronic A...  1500.0
# 2           2    Mercedes-Benz Mercedes A140 Elegance Piccadilly  1700.0
# 3           3                   Mercedes-Benz Mercedes-benz A160  1550.0
# 4           4     Mercedes-Benz CLK Coupe 200 Elegance Automatik  1200.0
#
#      milage      hubraum    transmission num_seats num_doors emission_class  \
# 0  278000.0  3564.923077  Schaltgetriebe        na        na             na
# 1  390000.0  1662.038633       Automatik        na        na             na
# 2  130000.0  1662.038633  Schaltgetriebe        na        na             na
# 3  154079.0  1662.038633       Automatik        na        na             na
# 4  175000.0  1998.000000       Automatik         4       2/3             na
#
#      car_type  ... elegance  tag_63  tag_65  tag_55 tüv E10  biodiesel  \
# 0      andere  ...        0       0       0       0   1   0          0
# 1   limousine  ...        0       0       0       0   0   0          0
# 2      andere  ...        1       0       0       0   0   0          0
# 3  kleinwagen  ...        0       0       0       0   0   0          0
# 4       sport  ...        1       0       0       0   0   0          0
#
#    pflanzenöl  electric  fueltype
# 0           0         0    Diesel
# 1           0         0    Benzin
# 2           0         0    Benzin
# 3           0         0    Benzin
# 4           0         0    Benzin
#
# [5 rows x 33 columns]

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'carname', 'price', 'milage', 'hubraum', 'transmission',
#        'num_seats', 'num_doors', 'emission_class', 'car_type', 'num_owners',
#        'age', 'power_ps', 'power_kw', 'Schaden', 'Model', 'amg', 'mc_laren',
#        'blk_series', 'blue_eff', 'g_pow', 'brabus', 'avantgarde', 'elegance',
#        'tag_63', 'tag_65', 'tag_55', 'tüv', 'E10', 'biodiesel', 'pflanzenöl',
#        'electric', 'fueltype'],
#       dtype='object')

# %% [markdown]
# ## 1. Categorical features

# %%
def count_boxplot(key):
    plt.figure(figsize=(12,5))
    plt.subplot(1,2,1)
    plt.title(key +' Histogram')
    sns.countplot(data=data, y=key,  order = data[key].value_counts().index, palette=("magma"))
    plt.subplot(1,2,2)
    plt.title(key +' vs Price')
    sns.boxplot(y=data[key], x=data.price, order = data[key].value_counts().index, palette=("magma"))
    plt.show()

# %%
def countplot(key, dataframe=data):
    sns.countplot(y=key, data=data, order = data[key].value_counts().index)

# %%
counts = data.Model.value_counts()
print(counts)
# Out:
# C-Klasse     2075
# E-Klasse     2003
# A-Klasse     1000
# S-Klasse      850
# GLE           845
# GLC           607
# V-Klasse      604
# OTHER         577
# B-Klasse      543
# CL            348
# Vito          315
# G-Klasse      293
# Sprinter      275
# CLA           272
# M-Klasse      203
# SL            190
# GLA           189
# GLS           136
# GT            133
# CLK           118
# Vaneo          97
# GLK            83
# GLB            55
# R-Klasse       53
# MarcoPolo      46
# GL             44
# CLC            20
# X-Klasse        1
# Name: Model, dtype: int64

# %%
count_boxplot('Model')

# %%
count_boxplot('transmission')

# %%
count_boxplot('fueltype')

# %%
count_boxplot('num_owners')

# %%
count_boxplot('emission_class')

# %%
count_boxplot('car_type')

# %%
countplot('Schaden')

# %%
countplot('amg')

# %% [markdown]
# ## 2. Numerical Data

# %% [markdown]
# ### 2.1. Price

# %%
sns.histplot(data.price, kde=True)

# %%
data.price.mean()

# %% [markdown]
# ### 2.2. Milage

# %%
fig, ax = plt.subplots(figsize=(8, 5)) 
sns.histplot(data.milage, kde=True)
ax.xaxis.set_major_formatter(ticker.EngFormatter())
plt.show()

# %% [markdown]
# ### 2.3. Power

# %%
sns.histplot(data.power_ps, kde=True)

# %%
sns.histplot(data.power_kw, kde=True)

# %%
data.power_ps.mean()

# %%
data.power_kw.mean()

# %% [markdown]
# ### 2.4. Age

# %%
sns.histplot(data.age, kde=True)

# %%
print('mean age of cars:', data.age.mean(), '[years]')

# %% [markdown]
# ### 2.5. Hubraum

# %%
sns.histplot(data.hubraum, kde=True)

# %%
def scatter_plot(key, hue=None, size=7, savename=None):
    fig = plt.figure(figsize=(4,4)) # 10 7
    sns.scatterplot(data=data, y='price', x=key, s=size, hue=hue, palette=("magma"))
    plt.title(key + ' vs. Price')
    plt.xlabel(key)
    plt.ylabel('Price')
    plt.tight_layout()
    plt.show()
    if savename is not None:
        fig.savefig('Plots/'+savename+'.png', format='png', dpi=100)

# %%
scatter_plot('milage', hue='amg', savename='price_milage2')

# %% [markdown]
# #### Inference
# - "price" negatively correlates with "milage" --> price decreases exponentially over "milage"
# - "price" seems to positively correlate with "AMG" tag

# %%
scatter_plot('power_ps', hue='age')

# %% [markdown]
# #### Inference
#
# - "power_ps" correlates positively with "price"
# - "age" is a indicator for price, too

# %%
scatter_plot('age', hue='emission_class')

# %% [markdown]
# #### Inference
#
# - You see how the emission classes groups the cars in different age stamps
# - price decreases exponentially with age
# - emission_class can be indicator for price, too
